# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from random_ts_generator import RandomDailyTSGenerator

# %%
a = RandomDailyTSGenerator('2016-04-01', '2019-04-01', peak_list=['2016-05-05', '2016-09-01'])

# %%
sample = next(a.generate_sample())

# %%
fig, ax = plt.subplots(1, figsize=(12,4))
plot(sample);

# %%
fig, ax = plt.subplots(1, figsize=(12,4))
plot(sample[:365]);
